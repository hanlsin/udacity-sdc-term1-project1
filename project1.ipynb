# %% [markdown]
# ## Test libraries.

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import cv2
# %matplotlib inline

# %%
from find_lane_lines import read_image

# %% [markdown]
# ## Test images.

# %%
test_images = ['./raw_images/solidWhiteCurve.jpg',
               './raw_images/solidWhiteRight.jpg',
               './raw_images/solidYellowCurve.jpg',
               './raw_images/solidYellowCurve2.jpg',
               './raw_images/solidYellowLeft.jpg',
               './whiteCarLandSwitch.jpg']

for img_path in test_images:
    org_img = read_image(img_path)
    plt.imshow(org_img)
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-13-c6424bcbb01b> in <module>()
#       8 for img_path in test_images:
#       9     org_img = read_image(img_path)
# ---> 10     plt.imshow(org_img)
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/pyplot.pyc in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, hold, data, **kwargs)
#    3156                         filternorm=filternorm, filterrad=filterrad,
#    3157                         imlim=imlim, resample=resample, url=url, data=data,
# -> 3158                         **kwargs)
#    3159     finally:
#    3160         ax._hold = washold
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1890                     warnings.warn(msg % (label_namer, func.__name__),
#    1891                                   RuntimeWarning, stacklevel=2)
# ...
